# %% [markdown]
# <a href="https://colab.research.google.com/github/BRCInc-dev/Data-Analysis-Tools/blob/main/Tips_dataset_analize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Savarankiškas užsiemimas: Išanalizuoti kavinės duomenis
# ### 2025-01-15
# #### Gabrielius Ravdonis

# %%
# Būtini bibliotekų importai
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# CSV failo įkėlimas
df = sns.load_dataset('tips')

# Duomenų struktūros peržiūra
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['sex'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['total_bill'].plot(kind='hist', bins=20, title='total_bill')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['tip'].plot(kind='hist', bins=20, title='tip')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['size'].plot(kind='hist', bins=20, title='size')
# ...

# %% [markdown]
# ### Duomenų stulpelių paaiškinimai:
# - **total_bill:** bendra sąskaitos suma
# - **tip:** palikti arbatpinigiai
# - **sex:** kliento lytis
# - **day:** savaitės diena
# - **time**: Laikas (pietūs, vakarienė)
# - **size:** svečių skaičius prie stalo

# %% [markdown]
# # Užduotys su `tips` duomenų rinkiniu
#
# ## 1. Duomenų analizė
# ### Užduotys:
# 1. Įkelkite `tips` duomenų rinkinį naudodami `seaborn.load_dataset()`.
#    - Peržiūrėkite pirmąsias 10 eilučių naudodami `head()`.
# 2. Patikrinkite stulpelių pavadinimus ir duomenų tipus naudodami `info()` (pasakykite kurie yra kiekybiniai, o kurie kokybiniai kintamieji).
# 3. Apskaičiuokite kiekvieno stulpelio trūkstamų reikšmių skaičių. (NA)
# 4. Apskaičiuokite minimalią, maksimalią, vidutinę ir medianinę reikšmes stulpeliams `total_bill`, `tip` ir `size`.
# 5. Raskite kiekvieno kategorinio stulpelio (`sex`, `smoker`, `day`, `time`) unikalias reikšmes ir jų dažnius naudodami `value_counts()`.
# 6. Apskaičiuokite kiekvienos dienos užsakymų skaičių ir apskaičiuokite vidutinį `total_bill` kiekvienai dienai.
#
# ## 2. Grupavimas ir statistiniai rodikliai
# ### Užduotys:
# 1. Grupėmis pagal `day` apskaičiuokite vidurkį, medianą, mažiausią ir didžiausią reikšmes stulpeliui `tip`.
# 2. Grupėmis pagal `smoker` ir `sex` apskaičiuokite vidutinį arbatpinigių procentą (procentą galite apskaičiuoti patys: `(tip / total_bill) * 100`).
# 3. Grupėmis pagal `time` ir `day` išanalizuokite vidutinę sąskaitą (`total_bill`) ir arbatpinigius (`tip`).
#
# ## 3. Duomenų vizualizacija
# ### Užduotys:
# 1. Sukurkite histogramą, kuri parodo `total_bill` reikšmių pasiskirstymą. Koks tai pasiskirstymas?
# 2. Sukurkite histogramą, kuri parodo `total_bill` reikšmių pasiskirstymąpagal kliento lyti? Ar grafikai skiriasi? Kas išleidžia vidutiniškai daugiau? Kieno sklaida didesnė?
# 2. Naudodami `sns.boxplot()` palyginkite `total_bill` reikšmes skirtingoms `day` reikšmėms. Trumpai painterpretuokite rezultatus.
# 3. Naudodami `sns.violinplot()` vizualizuokite `tip` dydžių pasiskirstymą pagal `smoker`. Trumpai painterpretuokite rezultatus.
# 4. Pavaizduokite `tip` priklausomybę nuo `total_bill` naudojant sklaidos diagramą `sns.scatterplot()`.
#
# ## 4. Koreliacija ir priklausomybės
# ### Užduotys:
# 1. Sukurkite koreliacijos matricą tarp skaitinių stulpelių (`total_bill`, `tip`, `size`) ir vizualizuokite ją naudodami `sns.heatmap()`.
# 2. Patikrinkite ryšį tarp sąskaitos dydžio (`total_bill`) ir arbatpinigių dydžio (`tip`) naudodami sklaidos diagramą (`scatterplot`).
# 3. Palyginkite ryšį tarp arbatpinigių procento ir grupės dydžio (`size`) naudojant sklaidos diagramą.
#
#
# ## 5. Kategorijų analizė ir įžvalgos
# ### Užduotys:
# 1. Kuri savaitės diena generuoja didžiausias pajamas?
# 2. Kuri savaitės diena surenka daugiausiai arbatpinigių?
# 3. Ar grupės dydis (`size`) turi įtakos arbatpinigių dydžiui?
# 4. Kuri grupė (`sex`, `smoker`) linkusi palikti didesnius arbatpinigius?
# 5. Ar yra skirtumas tarp pietų (`lunch`) ir vakarienės (`dinner`) užsakymų vidutinių sąskaitų?
# 6. Kuri produkto kategorija (pvz., `day`, `sex`) yra dažniausiai pasitaikanti duomenyse?

# %%
import pandas as pd

# Grupuojame pagal 'day' ir apskaičiuojame statistiką
day_stats = df.groupby('day')['tip'].agg(['mean', 'median', 'min', 'max'])

# Peržiūrime rezultatus
print(day_stats)
# Out:
#           mean  median   min    max
# day
# Thur  2.771452   2.305  1.25   6.70
# Fri   2.734737   3.000  1.00   4.73
# Sat   2.993103   2.750  1.00  10.00
# Sun   3.255132   3.150  1.01   6.50
# <ipython-input-2-b77b81fadc41>:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   day_stats = df.groupby('day')['tip'].agg(['mean', 'median', 'min', 'max'])
